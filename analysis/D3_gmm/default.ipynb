# %%
from functools import partial
import numpy as np
import os
import pandas as pd
import scipy

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt


import sys
sys.path.append('../')
import util

save_fig = partial(util.save_fig, save=True)

# %% [markdown]
# **Default parameters - will be replaced**

# %%
dataset_file = '/home/drake/workspace/em-2020/data/combined_dataset_subset_final.csv'
index_fields = ['Country', 'Year']
data_fields = ['ENI' ,'POP', 'URB', 'AFL' , 'TI', 'CTS' ,'KAOPEN']
prefix = 'template'
start_year = 1996
end_year = 2015
exclude_countries = []
pickle_file = '/home/drake/workspace/em-2020/analysis/D3_gmm/template_output.pickle.bz2'
pdynmc_params = {
    "use.mc.diff": True,
    "use.mc.lev": False,
    "use.mc.nonlin": False,
    "include.y": True,
    "varname.y": "ENI",
    "lagTerms.y": 2,
    "fur.con": True,
    "fur.con.diff": True,
    "fur.con.lev": False,
    "varname.reg.fur": ["POP", "AFL", "AFL2", "URB", "CTS", "TI", "KAOPEN"],
    "lagTerms.reg.fur": [0, 0, 0, 0, 0, 0, 0],
    "include.dum": True,
    "dum.diff": True,
    "dum.lev": False,
    "w.mat": "iid.err",
    "std.err": "corrected",
    "estimation": "twostep",
    "opt.meth": "none",
    "inst.stata": False,
}
plm_formula = 'ENI ~ lag(ENI, 1:2) + POP + AFL + AFL2 + URB + CTS + TI + KAOPEN | lag(ENI, 2:99)'
plm_params = {
    'effect': 'twoways',
    'model': 'twostep',
    'collapse': False,
    'transformation': 'd',
}

# %%
# Parameters
dataset_file = "/home/drake/workspace/em-2020/data/combined_dataset_subset_final.csv"
index_fields = ["Country", "Year"]
data_fields = ["ENI", "POP", "URB", "AFL", "TI", "TS", "CTS", "KAOPEN"]
prefix = "template"
start_year = 1996
end_year = 2015
exclude_countries = []
pdynmc_params = {
    "use.mc.diff": True,
    "use.mc.lev": False,
    "use.mc.nonlin": False,
    "include.y": True,
    "varname.y": "ENI",
    "lagTerms.y": 2,
    "fur.con": True,
    "fur.con.diff": True,
    "fur.con.lev": False,
    "varname.reg.fur": ["POP", "AFL", "AFL2", "URB", "CTS", "TI", "KAOPEN"],
    "lagTerms.reg.fur": [0, 0, 0, 0, 0, 0, 0],
    "include.dum": True,
    "dum.diff": True,
    "dum.lev": False,
    "w.mat": "iid.err",
    "std.err": "corrected",
    "estimation": "twostep",
    "opt.meth": "none",
    "inst.stata": False,
}
pickle_file = "/home/drake/workspace/em-2020/analysis/D3_gmm/default.pickle.bz2"

# %% [markdown]
# **End of parameter section**

# %%
%get dataset_file index_fields data_fields start_year end_year exclude_countries 
%get pdynmc_params plm_formula plm_params

# SoS mangles dict keys, for no apparent reason
names(pdynmc_params) <- gsub('_', '.', names(pdynmc_params))
names(plm_params) <- gsub('_', '.', names(plm_params))

suppressMessages({
library(dplyr)
library(plm)
library(pdynmc)
})
`%notin%` <- Negate(`%in%`)

data.df <- subset(
    read.csv(dataset_file), select=c(index_fields, data_fields),
    subset=(Country %notin% exclude_countries) 
    & (start_year <= Year) & (Year <= end_year)
)
data.df['AFL2'] = data.df['AFL']^2
data.panel <- pdata.frame(data.df, index = c("Country", "Year"), drop.index = TRUE, row.names=TRUE)

head(data.df %>% 
    group_by(Country) %>% 
    summarize(min=min(Year), max=max(Year), .groups='drop'))
# Out:
#   Country min  max
# 1 ARG     1996 2014
# 2 AUS     1996 2015
# 3 BGR     1996 2014
# 4 BRA     1996 2014
# 5 CAN     1996 2015
# 6 CHE     1996 2014

# %%
pdynmc_params
# Out:
# $use.mc.diff
# [1] TRUE
#
# $use.mc.lev
# [1] FALSE
#
# $use.mc.nonlin
# [1] FALSE
#
# $include.y
# [1] TRUE
#
# $varname.y
# [1] "ENI"
#
# $lagTerms.y
# [1] 2
#
# $fur.con
# [1] TRUE
#
# $fur.con.diff
# [1] TRUE
#
# $fur.con.lev
# [1] FALSE
#
# $varname.reg.fur
# [1] "POP"    "AFL"    "AFL2"   "URB"    "CTS"    "TI"     "KAOPEN"
#
# $lagTerms.reg.fur
# [1] 0 0 0 0 0 0 0
#
# $include.dum
# [1] TRUE
#
# $dum.diff
# [1] TRUE
#
# $dum.lev
# [1] FALSE
#
# $w.mat
# [1] "iid.err"
#
# $std.err
# [1] "corrected"
#
# $estimation
# [1] "twostep"
#
# $opt.meth
# [1] "none"
#
# $inst.stata
# [1] FALSE

# %%
pdynmc_base_params <- list(dat = data.df, 
                    varname.i = "Country", varname.t = "Year", varname.dum = "Year")

pdynmc_fit <- do.call(pdynmc, modifyList(pdynmc_base_params, pdynmc_params))
pdynmc_summary <- summary(pdynmc_fit)
pdynmc_summary
# Out:
# Dynamic linear panel estimation (twostep)
# Estimation steps: 2
#
# Coefficients:
#             Estimate Std.Err.rob z-value.rob Pr(>|z.rob|)
# L1.ENI     0.3936476   0.8934647       0.441       0.6592
# L2.ENI    -0.2805612   1.1825981      -0.237       0.8127
# L0.POP    -0.0234170   0.0673114      -0.348       0.7278
# L0.AFL     0.0423875   0.1031161       0.411       0.6811
# L0.AFL2   -0.0372387   0.0089953      -4.140        3e-05 ***
# L0.URB     0.0260173   0.1165842       0.223       0.8235
# L0.CTS     0.2246844   0.1821795       1.233       0.2176
# L0.TI      0.0291502   0.0159813       1.824       0.0682 .
# L0.KAOPEN  0.0005211   0.0200476       0.026       0.9793
# 1999      -0.0131719   0.0372405      -0.354       0.7233
# 2000      -0.0326754   0.0247201      -1.322       0.1862
# 2001      -0.0217710   0.0174454      -1.248       0.2120
# 2002      -0.0295920   0.0552093      -0.536       0.5920
# 2003      -0.0216789   0.0693602      -0.313       0.7543
# 2004      -0.0313252   0.0851223      -0.368       0.7129
# 2005      -0.0352720   0.0795320      -0.443       0.6578
# 2006      -0.0524515   0.0943418      -0.556       0.5782
# 2007      -0.0568246   0.0921424      -0.617       0.5372
# 2008      -0.0736555   0.1196152      -0.616       0.5379
# 2009      -0.0772810   0.1769306      -0.437       0.6621
# 2010      -0.0821731   0.2104713      -0.390       0.6965
# 2011      -0.1239223   0.2160748      -0.574       0.5660
# 2012      -0.1066930   0.1950143      -0.547       0.5844
# 2013      -0.1159708   0.2503069      -0.463       0.6434
# 2014      -0.1306654   0.2619288      -0.499       0.6178
# 2015      -0.1182964   0.2758229      -0.429       0.6679
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  194 total instruments are employed to estimate 26 parameters
#  170 linear (DIF)
#  7 further controls (DIF)
#  17 time dummies (DIF)
#
# J-Test (overid restrictions):  0 with 168 DF, pvalue: 1
# F-Statistic (slope coeff):  3376.1 with 9 DF, pvalue: <0.001
# F-Statistic (time dummies):  426.96 with 17 DF, pvalue: <0.001

# %%
pdynmc_resid <- data.frame(residuals=unlist(residuals(pdynmc_fit)),
                           fitted=unlist(fitted.values(pdynmc_fit)))
resid.reg <- lm(residuals ~ fitted, data=pdynmc_resid)
plot(pdynmc_fit)
abline(resid.reg, col='darkred')
summary(resid.reg)
# Out:
# Call:
# lm(formula = residuals ~ fitted, data = pdynmc_resid)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.103347 -0.020643  0.000765  0.020955  0.129795
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.021816   0.002727  -8.001 1.67e-14 ***
# fitted      -0.567053   0.054086 -10.484  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.03484 on 364 degrees of freedom
#   (8 observations deleted due to missingness)
# Multiple R-squared:  0.2319,	Adjusted R-squared:  0.2298
# F-statistic: 109.9 on 1 and 364 DF,  p-value: < 2.2e-16
# Plot with title “Fitted Residual Plot of pdynmc_fit”

# %%
jtest.fct(pdynmc_fit)
ser.corr1 <- mtest.fct(pdynmc_fit, t.order = 1)
ser.corr1
ser.corr2 <- mtest.fct(pdynmc_fit, t.order = 2)
ser.corr2
# Out:
# 	J-Test of Hansen
#
# data:  2step GMM Estimation; H0: overidentifying restrictions valid
# chisq = -3.5796e-15, df = 168, p-value = 1
# 	Arrelano and Bond (1991) serial correlation test of degree 1
#
# data:  2step GMM Estimation; H0: no serial correlation of order 1 in the error terms
# normal = -0.32196, p-value = 0.7475
# 	Arrelano and Bond (1991) serial correlation test of degree 2
#
# data:  2step GMM Estimation; H0: no serial correlation of order 2 in the error terms
# normal = 0.26692, p-value = 0.7895

# %%
pdynmc_tests <- do.call(rbind, lapply(
    list(pdynmc_summary$hansenj, pdynmc_summary$slopef, pdynmc_summary$time.dumf, ser.corr1, ser.corr2),
    function(x) {
        data.frame(stat=as.numeric(x$statistic), test=names(x$statistic),
                   p.value=x$p.value, row.names=x$method, result=x$data.name)
    }
))
pdynmc_tests
# Out:
#                                                              stat
# J-Test of Hansen                                             -3.579612e-15
# Wald test                                                     3.376104e+03
# Wald test1                                                    4.269586e+02
# Arrelano and Bond (1991) serial correlation test of degree 1 -3.219577e-01
# Arrelano and Bond (1991) serial correlation test of degree 2  2.669230e-01
#                                                              test
# J-Test of Hansen                                             chisq
# Wald test                                                    chisq
# Wald test1                                                   chisq
# Arrelano and Bond (1991) serial correlation test of degree 1 normal
# Arrelano and Bond (1991) serial correlation test of degree 2 normal
#                                                              p.value
# J-Test of Hansen                                             1.000000e+00
# Wald test                                                    0.000000e+00
# Wald test1                                                   4.222262e-80
# Arrelano and Bond (1991) serial correlation test of degree 1 7.474847e-01
# Arrelano and Bond (1991) serial correlation test of degree 2 7.895284e-01
#                                                              result
# J-Test of Hansen                                             2step GMM Estimation; H0: overidentifying restrictions valid
# Wald test                                                    2step GMM Estimation; H0: slope parameters are jointly zero
# Wald test1                                                   2step GMM Estimation; H0: time.dum parameters are jointly zero
# Arrelano and Bond (1991) serial correlation test of degree 1 2step GMM Estimation; H0: no serial correlation of order 1 in the error terms
# Arrelano and Bond (1991) serial correlation test of degree 2 2step GMM Estimation; H0: no serial correlation of order 2 in the error terms

# %%
# plm.formula <- as.formula(plm_formula)
# plm.params = modifyList(list(plm.formula,
#                              data=data.panel),
#                         plm_params)
# z2 <- do.call(pgmm, plm.params)
# z2$call <- plm.formula
# summary(z2, robust = TRUE)

# %%
pdynmc_coef <- data.frame(pdynmc_summary$coefficients)

# %%
%get pdynmc_coef pdynmc_tests pdynmc_resid --from R
import pickle
import bz2

with bz2.BZ2File(pickle_file, 'w') as fd:
    pickle.dump({
        'pdynmc_coef': pdynmc_coef,
        'pdynmc_tests': pdynmc_tests,
        'pdynmc_resid': pdynmc_resid,
        'pdynmc_params': pdynmc_params,
        'start_year': start_year,
        'end_year': start_year,
        'varname.reg.fur': start_year,
        'start_year': start_year,
    }, fd)
